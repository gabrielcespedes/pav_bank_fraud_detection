# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = '../data/Variant_I.csv'
file2 = '../data/Variant_II.csv'
file3 = '../data/Variant_III.csv'
file4 = '../data/Variant_IV.csv'

df1 = pd.read_csv(file1, sep=",")
df2 = pd.read_csv(file2, sep=",")
df3 = pd.read_csv(file3, sep=",")
df4 = pd.read_csv(file4, sep=",")

# %%
df = pd.concat([df1, df2, df3, df4], axis = 0)
df.head(2)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  foreign_request  \
# 0              102.453711           AA          1059  ...                0
# 1               -0.849551           AD          1658  ...                0
#
#      source  session_length_in_minutes  device_os  keep_alive_session  \
# 0  INTERNET                  16.224843      linux                   1
# 1  INTERNET                   3.363854      other                   1
#
#   device_distinct_emails_8w  device_fraud_count  month  x1  x2
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
#
#    intended_balcon_amount payment_type  zip_count_4w   velocity_6h  \
# 0              102.453711           AA          1059  13096.035018
# 1               -0.849551           AD          1658   9223.283431
#
#    velocity_24h  velocity_4w  bank_branch_count_8w  \
# 0   7850.955007  6742.080561                     5
# 1   5745.251481  5941.664859                     3
#
#    date_of_birth_distinct_emails_4w employment_status  credit_risk_score  \
# 0                                 5                CB                163
# ...

# %%
df.shape
# Out:
# (4000000, 34)

# %%
from exploracion7 import *

# %%
calidad_datos(df)
# Out:
#                                      tipo  %_nan     %_ceros      count  \
# fraud_bool                          int64    0.0   98.897050  4000000.0
# month                               int64    0.0   10.623300  4000000.0
# device_fraud_count                  int64    0.0  100.000000  4000000.0
# device_distinct_emails_8w           int64    0.0    0.659975  4000000.0
# keep_alive_session                  int64    0.0   43.770950  4000000.0
# foreign_request                     int64    0.0   97.554225  4000000.0
# has_other_cards                     int64    0.0   75.853900  4000000.0
# bank_months_count                   int64    0.0    0.000000  4000000.0
# phone_mobile_valid                  int64    0.0   13.523875  4000000.0
# phone_home_valid                    int64    0.0   52.680000  4000000.0
# email_is_free                       int64    0.0   47.751775  4000000.0
# date_of_birth_distinct_emails_4w    int64    0.0    0.306850  4000000.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1071280)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2928720, 34)

# %%
df['fraud_bool'].value_counts()
# Out:
# fraud_bool
# 0    2895348
# 1      33372
# Name: count, dtype: int64

# %%
df.drop(columns = ["x1", "x2"], inplace = True)

# %%
calidad_datos(df)
# Out:
#                                      tipo  %_nan     %_ceros      count  \
# fraud_bool                          int64    0.0   98.860526  2928720.0
# device_distinct_emails_8w           int64    0.0    0.654245  2928720.0
# keep_alive_session                  int64    0.0   43.566746  2928720.0
# foreign_request                     int64    0.0   97.551183  2928720.0
# has_other_cards                     int64    0.0   76.050834  2928720.0
# bank_months_count                   int64    0.0    0.000000  2928720.0
# phone_mobile_valid                  int64    0.0   13.184156  2928720.0
# phone_home_valid                    int64    0.0   53.298199  2928720.0
# email_is_free                       int64    0.0   47.698619  2928720.0
# credit_risk_score                   int64    0.0    0.046915  2928720.0
# device_fraud_count                  int64    0.0  100.000000  2928720.0
# date_of_birth_distinct_emails_4w    int64    0.0    0.286644  2928720.0
# ...

# %%
graficos(calidad_datos(df), df, ['fraud_bool', 'income', 'customer_age', 'payment_type', 'bank_branch_count_8w', 'employment_status'])

# %%
graficos(calidad_datos(df), df, ['credit_risk_score', 'email_is_free', 'housing_status', 'bank_months_count', 'has_other_cards', 'proposed_credit_limit'])

# %%
graficos(calidad_datos(df), df, ['foreign_request', 'source', 'session_length_in_minutes', 'device_os', 'keep_alive_session', 'device_distinct_emails_8w'])

# %%
variables = ['income', 'customer_age', 'payment_type', 'bank_branch_count_8w', 'employment_status', 'credit_risk_score', 'email_is_free', 'housing_status', 'session_length_in_minutes', 'device_os']

# %%
ncols = 2
nrows = (len(variables) + 1) // ncols

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 10))
axes = axes.flatten()

for i, var in enumerate(variables):
    sns.histplot(data=df, x=var, hue='fraud_bool', ax=axes[i])
    axes[i].set_title(f'Distribución de {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Frecuencia')

# Oculta ejes no usados si la cuadrícula es impar
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df_negativa = df[df['fraud_bool'] == 0]
df_aleatorio = df_negativa.sample(n = 33372, random_state = 42)
df_positiva = df[df['fraud_bool'] == 1]
df_aleatorio = pd.concat([df_aleatorio, df_positiva], axis = 0)
df_aleatorio["fraud_bool"].value_counts()
# Out:
# fraud_bool
# 0    33372
# 1    33372
# Name: count, dtype: int64

# %%
ncols = 2
nrows = (len(variables) + 1) // ncols

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 10))
axes = axes.flatten()

for i, var in enumerate(variables):
    sns.histplot(data=df_aleatorio, x=var, hue='fraud_bool', ax=axes[i])
    axes[i].set_title(f'Distribución de {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Frecuencia')

# Oculta ejes no usados si la cuadrícula es impar
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df.head(2)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
#
#    intended_balcon_amount payment_type  zip_count_4w   velocity_6h  \
# 0              102.453711           AA          1059  13096.035018
# 1               -0.849551           AD          1658   9223.283431
#
#    velocity_24h  velocity_4w  bank_branch_count_8w  \
# 0   7850.955007  6742.080561                     5
# 1   5745.251481  5941.664859                     3
#
#    date_of_birth_distinct_emails_4w employment_status  credit_risk_score  \
# 0                                 5                CB                163
# ...

# %%
df.drop(columns = ["credit_risk_score"], inplace = True)

# %%
informe = calidad_datos(df)

# %%
informe
# Out:
#                                      tipo  %_nan     %_ceros      count  \
# fraud_bool                          int64    0.0   98.860526  2928720.0
# device_distinct_emails_8w           int64    0.0    0.654245  2928720.0
# keep_alive_session                  int64    0.0   43.566746  2928720.0
# foreign_request                     int64    0.0   97.551183  2928720.0
# has_other_cards                     int64    0.0   76.050834  2928720.0
# bank_months_count                   int64    0.0    0.000000  2928720.0
# phone_mobile_valid                  int64    0.0   13.184156  2928720.0
# phone_home_valid                    int64    0.0   53.298199  2928720.0
# email_is_free                       int64    0.0   47.698619  2928720.0
# device_fraud_count                  int64    0.0  100.000000  2928720.0
# date_of_birth_distinct_emails_4w    int64    0.0    0.286644  2928720.0
# bank_branch_count_8w                int64    0.0   14.220035  2928720.0
# ...

# %%
categoricas = list(informe[informe['tipo'] == "object"].index)
categoricas
# Out:
# ['source', 'housing_status', 'device_os', 'payment_type', 'employment_status']

# %%
df[categoricas + ['fraud_bool']]
# Out:
#           source housing_status device_os payment_type employment_status  \
# 0       INTERNET             BC     linux           AA                CB
# 1       INTERNET             BC     other           AD                CA
# 2       INTERNET             BC   windows           AB                CA
# 3       INTERNET             BC     linux           AB                CA
# 4       INTERNET             BC     other           AA                CA
# ...          ...            ...       ...          ...               ...
# 999935  INTERNET             BB   windows           AB                CB
# 999946  INTERNET             BC   windows           AB                CA
# 999953  INTERNET             BC     linux           AA                CA
# 999963  INTERNET             BB     linux           AC                CF
# 999980  INTERNET             BC     other           AD                CA
#
#         fraud_bool
# 0                0
# 1                0
# 2                0
# ...

# %%
correlacion(df[categoricas + ['fraud_bool', 'income', 'customer_age', 'bank_branch_count_8w','session_length_in_minutes' ]], \
            'fraud_bool', dicotomic = True)
# Out:
# Correlación de Pearson entre fraud_bool y fraud_bool: 1.00
# Correlación de Pearson entre income y fraud_bool: 0.04
# Correlación de Pearson entre customer_age y fraud_bool: 0.05
# Correlación de Pearson entre bank_branch_count_8w y fraud_bool: -0.01
# Correlación de Pearson entre session_length_in_minutes y fraud_bool: 0.01
# Chi-cuadrado entre source y fraud_bool: 31.69, p-value: 0.0000. Hay relación entre las variables.
# Chi-cuadrado entre housing_status y fraud_bool: 34102.81, p-value: 0.0000. Hay relación entre las variables.
# Chi-cuadrado entre device_os y fraud_bool: 18332.42, p-value: 0.0000. Hay relación entre las variables.
# Chi-cuadrado entre payment_type y fraud_bool: 4788.53, p-value: 0.0000. Hay relación entre las variables.
# Chi-cuadrado entre employment_status y fraud_bool: 3893.97, p-value: 0.0000. Hay relación entre las variables.
# (['fraud_bool',
#   'income',
#   'customer_age',
#   'bank_branch_count_8w',
#   'session_length_in_minutes'],
#  ['source',
# ...

# %%
df.head(2)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
#
#    intended_balcon_amount payment_type  zip_count_4w   velocity_6h  \
# 0              102.453711           AA          1059  13096.035018
# 1               -0.849551           AD          1658   9223.283431
#
#    velocity_24h  velocity_4w  bank_branch_count_8w  \
# 0   7850.955007  6742.080561                     5
# 1   5745.251481  5941.664859                     3
#
#    date_of_birth_distinct_emails_4w employment_status  email_is_free  \
# 0                                 5                CB              1
# ...

# %%
df.to_csv("../data/datos_preprocesados.csv", sep=",", index = False)

# %%
with open("config_vars.py", "w", encoding="utf-8") as f:
    f.write(f"categoricas = {categoricas}")
